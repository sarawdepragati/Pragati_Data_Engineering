# %%
# %run "/Workspace/Users/sarawdepragati1969@gmail.com/Pragati_Data_Engineering/Notebooks/bronze/nb_customer_bronze_2026-05-19 17_43_43"

# %%
# %run "/Workspace/Users/sarawdepragati1969@gmail.com/Pragati_Data_Engineering/Notebooks/silver/nb_customer_bronze_silver_2026-05-19 17_46_03"

# %%
# %run "/Workspace/Users/sarawdepragati1969@gmail.com/Pragati_Data_Engineering/Notebooks/gold/nb_customer_silver_gold_2026-05-19 17_51_29"

# %%
# %sql
select COUNT(*) from saleslake_dev.bronze_dev.rawcustomer;
select Count(*) from saleslake_dev.silver_dev.cleanedcustomer;
select count(*) from saleslake_dev.gold_dev.refinedcustomer

# %%
# %sql
select Count(*) from saleslake_dev.silver_dev.cleanedcustomer;

# %%
# %sql
select count(*) from saleslake_dev.gold_dev.refinedcustomer
