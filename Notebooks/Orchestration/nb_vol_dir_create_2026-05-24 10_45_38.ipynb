# %%
dbutils.fs.mkdirs('/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_customer/')

dbutils.fs.mkdirs('/Volumes/saleslake_prod/bronze_prod/vol_saleslake_src_files_prod/daily_customer/')

dbutils.fs.mkdirs('/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_customer/')




dbutils.fs.mkdirs('/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_sales/')

dbutils.fs.mkdirs('/Volumes/saleslake_prod/bronze_prod/vol_saleslake_src_files_prod/daily_sales/')

dbutils.fs.mkdirs('/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_sales/')
