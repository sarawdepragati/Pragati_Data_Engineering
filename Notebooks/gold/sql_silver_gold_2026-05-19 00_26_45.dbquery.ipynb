-- %%
CREATE OR REPLACE TABLE my_catalog_pragati.gold_schema.RefinedMonthlySales
(
    sale_id INTEGER, product STRING, category STRING, quantity INTEGER, price DOUBLE, sale_date date, region STRING, ingest_ts TIMESTAMP, initial_load_ts TIMESTAMP,last_updt_ts TIMESTAMP
);

describe my_catalog_pragati.gold_schema.RefinedMonthlySales;
 
SELECT * FROM my_catalog_pragati.gold_schema.RefinedMonthlySales;
