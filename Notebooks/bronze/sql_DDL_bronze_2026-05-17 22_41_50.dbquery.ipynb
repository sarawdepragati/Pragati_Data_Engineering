-- %%
CREATE OR REPLACE TABLE my_catalog_pragati.bronze_schema.raw_monthly_sales
(
    sale_id STRING, product STRING, category STRING, quantity STRING, price STRING, sale_date STRING, region STRING, ingest_ts TIMESTAMP
);

describe my_catalog_pragati.bronze_schema.raw_monthly_sales;

SELECT * FROM my_catalog_pragati.bronze_schema.raw_monthly_sales;
