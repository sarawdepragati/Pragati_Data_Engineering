-- %%
CREATE OR REPLACE TABLE my_catalog_pragati.silver_schema.cleanedMonthlySales
(
    sale_id INTEGER, product STRING, category STRING, quantity INTEGER, price DOUBLE, sale_date date, region STRING, ingest_ts TIMESTAMP
);

describe my_catalog_pragati.silver_schema.cleanedmonthlysales;
 
SELECT * FROM my_catalog_pragati.silver_schema.cleanedMonthlySales;
