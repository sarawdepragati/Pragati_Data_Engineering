# %%
dbutils.widgets.text(
    name='catalogName',
    label='Enter catalog Name',
    defaultValue='my_catalog_pragati'
)

catalog_name = dbutils.widgets.get('catalogName')

dbutils.widgets.text(
    name='schemaName',
    label='Enter schema Name',
    defaultValue='schema_bronze'
)

schema_name = dbutils.widgets.get('schemaName')


dbutils.widgets.text(
    name='SourceFileLocation',
    label='Enter Source File Location',
    defaultValue='/Volumes/my_catalog_pragati/bronze_schema/landing_files/src_files/monthly_sales/'
)
source_file_location = dbutils.widgets.get('SourceFileLocation')

# %%
print(catalog_name)
print(schema_name)
print(source_file_location)

# %%
tableName=f"{catalog_name}.{schema_name}.raw_monthly_sales"
print(tableName)
